# %% [markdown]
# # monthly test

# %%
#1
count=0
str=input("enter the string: ")
chr=input("enter the character: ")
for i in str:
    if chr in i:
        count+=1
    else:
        count+=0
print(count)
#2
str2=input("enter the word: ")
for j in range(-1,-len(str2)-1,-1):
    print(str2[j],end="")
#3
str3=input("enter the word: ")
status=False
for k in range(len(str3)):
    if str3[k]==str3[len(str3)-1-k]:
        status=True
    else:
        status=False
if status==True:
    print(f"the word {str3} is a palindrome")
else:
    print(f"the word {str3} is not a palindrome")
#4
count1=0
str2=input("enter the word to count vowels: ")
for j in str2:
    if j=="a" or j=="e" or j=="i" or j=="o" or j=="u":
        count1+=1
    else:
        count1+=0
print("the no of vowels in",str2,"is",count1)
#5
str3=input("enter the sentence: ")
for k in str3:
    if k==" ":
        k="_"
    print(k,end="")
print(str3.replace(" ","_"))
# Out:
# 0
# JKHJKKJthe word MMMMM is a palindrome
# the no of vowels in  is 0

# %% [markdown]
# # real life problems

# %%
item1=(input("enter the name of the item 1:"))
quantity1=int(input(f"enter the no of {item1}"))
price1=int(input(f"enter the price of the {item1}"))
item2=(input("enter the name of the item 2:"))
quantity2=int(input(f"enter the no of {item2}"))
price2=int(input(f"enter the price of the {item2}"))
item3=(input("enter the name of the item 3:"))
quantity3=int(input(f"enter the no of {item3}"))
price3=int(input(f"enter the price of the {item3}"))
print("THE TOTAL BILL IS :")
cost1=quantity1*price1
cost2=quantity2*price2
cost3=quantity3*price3
totalcost=cost1+cost2+cost3
print("the total bill is",totalcost)
if totalcost>1000:
    discount=(10/100)*totalcost
    print("the final bill is",totalcost-discount)
print("bye bye visit again")
# Out:
# THE TOTAL BILL IS :
# the total bill is 1590
# the final bill is 1431.0
# bye bye
